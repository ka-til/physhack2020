# %%
import numpy as np
import matplotlib.pylab as plt

# %%
wavenumberO2 = np.loadtxt('wavenumber_atm_O2.txt.csv', delimiter=',')
transmittanceO2 = np.loadtxt('transmittance_spectrum_atm_O2.txt.csv', delimiter=',')

# %matplotlib notebook
plt.plot(wavenumberO2, np.log(1/transmittanceO2))
plt.title('Oxygen Absorption spectrum')
plt.xlabel('Wavenumber[cm^-1]', fontsize = 18)
plt.ylabel('Absorbance', fontsize = 18)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Absorbance')

# %%
wavenumberCO2 = np.loadtxt('wavenumber_atm_CO2.csv', delimiter=',')
transmittanceCO2 = np.loadtxt('transmittance_spectrum_atm_CO2.csv', delimiter=',')

# %matplotlib notebook
plt.plot(wavenumberCO2, np.log(1/transmittanceCO2))
plt.title('CO2 Absorption spectrum')
plt.xlabel('Wavenumber[cm^-1]', fontsize = 18)
plt.ylabel('Absorbance', fontsize = 18)
# Out:
# <ipython-input-12-780aa6b8abfb>:5: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(wavenumberCO2, np.log(1/transmittanceCO2))
# <ipython-input-12-780aa6b8abfb>:5: RuntimeWarning: overflow encountered in true_divide
#   plt.plot(wavenumberCO2, np.log(1/transmittanceCO2))
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Absorbance')

# %%
wavenumberCO = np.loadtxt('wavenumber_atm_CO.csv', delimiter=',')
transmittanceCO = np.loadtxt('transmittance_spectrum_atm_CO.csv', delimiter=',')

# %matplotlib notebook
plt.plot(wavenumberCO, np.log(1/transmittanceCO))
plt.title('CO Absorption spectrum')
plt.xlabel('Wavenumber[cm^-1]', fontsize = 18)
plt.ylabel('Absorbance', fontsize = 18)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Absorbance')

# %%
wavenumberN2 = np.loadtxt('wavenumber_atm_N2.csv', delimiter=',')
transmittanceN2 = np.loadtxt('transmittance_spectrum_atm_N2.csv', delimiter=',')

# %matplotlib notebook
plt.plot(wavenumberN2, np.log(1/transmittanceN2))
plt.title('N2 Absorption spectrum')
plt.xlabel('Wavenumber[cm^-1]', fontsize = 18)
plt.ylabel('Absorbance', fontsize = 18)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Absorbance')

# %%
wavenumberH2O = np.loadtxt('wavenumber_atm_H2O.csv', delimiter=',')
transmittanceH2O = np.loadtxt('transmittance_spectrum_atm_H2O.csv', delimiter=',')

# %matplotlib notebook
plt.plot(wavenumberH2O, np.log(1/transmittanceH2O))
plt.title('H2O Absorption spectrum')
plt.xlabel('Wavenumber[cm^-1]', fontsize = 18)
plt.ylabel('Absorbance', fontsize = 18)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Absorbance')

# %%
wavenumberSO2 = np.loadtxt('wavenumber_atm_SO2.csv', delimiter=',')
transmittanceSO2 = np.loadtxt('transmittance_spectrum_atm_SO2.csv', delimiter=',')

# %matplotlib notebook
plt.plot(wavenumberSO2, np.log(1/transmittanceSO2))
plt.title('SO2 Absorption spectrum')
plt.xlabel('Wavenumber[cm^-1]', fontsize = 18)
plt.ylabel('Absorbance', fontsize = 18)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0, 0.5, 'Absorbance')

# %%
plt.plot(wavenumberN2, np.log10(np.log(1/transmittanceN2)), c='skyblue')
plt.plot(wavenumberSO2, np.log10(np.log(1/transmittanceSO2)), c='skyblue')
plt.plot(wavenumberH2O, np.log10(np.log(1/transmittanceH2O)), c='skyblue')
plt.plot(wavenumberCO, np.log10(np.log(1/transmittanceCO)), c='skyblue')
plt.plot(wavenumberCO2, np.log10(np.log(1/transmittanceCO2)), c='skyblue')
#plt.plot(wavenumberO2, np.log10(np.log(1/transmittanceO2)), c='r')
plt.title('Venus Atmosphere', fontsize = 12)
plt.xlabel('Wavenumber[cm^-1]', fontsize = 18)
plt.ylabel('log(Absorbance)', fontsize = 18)
# Out:
# <ipython-input-37-94943ea46c15>:1: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(wavenumberN2, np.log10(np.log(1/transmittanceN2)), c='skyblue')
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <ipython-input-37-94943ea46c15>:5: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(wavenumberCO2, np.log10(np.log(1/transmittanceCO2)), c='skyblue')
# <ipython-input-37-94943ea46c15>:5: RuntimeWarning: overflow encountered in true_divide
#   plt.plot(wavenumberCO2, np.log10(np.log(1/transmittanceCO2)), c='skyblue')
# Text(0, 0.5, 'log(Absorbance)')
